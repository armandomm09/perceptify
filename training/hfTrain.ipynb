# %%
# !pip install datasets transformers accelerate torch scikit-learn matplotlib wandb
# Out:
# ...
#   Using cached fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached GitPython-3.1.43-py3-none-any.whl.metadata (13 kB)
# ...
#   Using cached attrs-24.2.0-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# ...
#   Using cached smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 275.0 kB/s eta 0:00:0000:010:02
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 250.2 kB/s eta 0:00:00a 0:00:02
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.2/15.2 MB 237.3 kB/s eta 0:00:0000:0200:03
# ...
# Using cached fsspec-2024.9.0-py3-none-any.whl (179 kB)
# ...
# Using cached GitPython-3.1.43-py3-none-any.whl (207 kB)
# ...
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.5/29.5 MB 417.1 kB/s eta 0:00:0000:0100:03
# ...

# %%
from datasets import load_dataset

dataset = load_dataset("/Users/armando/Progra/python/cv/fall-detection/Fall-Detection-4")
